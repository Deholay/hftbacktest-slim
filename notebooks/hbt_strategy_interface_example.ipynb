# %% [markdown]
# # __Futures/Spot HBT Strategy Interface Example__
#
# This notebook follows the same staged shape as `hbt_pair_backtest_visualization.ipynb`, but imports the project-level strategy contract from `scripts.strategy_api` and the futures/spot implementation adapter from `future_spot.arbitrage.strategy_adapter`.

# %%
from argparse import Namespace
from pathlib import Path
import sys

import pandas as pd

pd.set_option("display.max_columns", 100)
pd.set_option("display.width", 200)

NOTEBOOK_DIR = Path.cwd().resolve()
PROJECT_ROOT = NOTEBOOK_DIR.parent
FUTURE_SPOT_ROOT = PROJECT_ROOT / "future_spot"

for path in (PROJECT_ROOT, FUTURE_SPOT_ROOT):
    text = str(path)
    if text not in sys.path:
        sys.path.insert(0, text)

from scripts.strategy_api import StrategyContext, StrategyDecision
from future_spot.arbitrage.strategy_adapter import FutureSpotPairStrategy
from future_spot.arbitrage import daily_pipeline, event_data, hbt_pipeline, reporting

# %% [markdown]
# ## __Parameters__

# %%
args = Namespace(
    start_date="2026-05-21",
    end_date="2026-05-26",
    base_config=FUTURE_SPOT_ROOT / "arbitrage_config_base.json",
    calendar=FUTURE_SPOT_ROOT / "Calendar.csv",
    stockinfo=FUTURE_SPOT_ROOT / "stockinfo.csv",
    output_dir=FUTURE_SPOT_ROOT / "output" / "hbt_strategy_interface_example",
    futures_parquet_template=daily_pipeline.DEFAULT_FUTURES_PARQUET_TEMPLATE,
    twse_daytrade_template=daily_pipeline.DEFAULT_TWSE_DAYTRADE_TEMPLATE,
    tpex_daytrade_template=daily_pipeline.DEFAULT_TPEX_DAYTRADE_TEMPLATE,
    twse_daily_template=daily_pipeline.DEFAULT_TWSE_DAILY_TEMPLATE,
    tpex_daily_template=daily_pipeline.DEFAULT_TPEX_DAILY_TEMPLATE,
    build_session_start="08:45:00",
    build_session_end="13:45:00",
    min_future_volume=100,
    min_stock_volume=1_000_000,
    required_unit=2000,
    name_template="{spot_symbol}_{future_symbol}",
    rebuild_daily_configs=False,
    session_start="09:00:00",
    session_end="13:30:00",
    pair_name=[],
    max_pairs=1,
    no_convert_missing_event_data=True,
    rebuild_event_data=False,
    conversion_qa_sample_rows=1000,
    spot_input_csv_template=event_data.DEFAULT_SPOT_INPUT_CSV_TEMPLATE,
    data_platform_base="/mnt/z/數據平台",
    event_futures_parquet_dir=None,
    first_leg="future",
    step_ms=1000.0,
    order_latency_ms=0.0,
    response_latency_ms=0.0,
    feed_latency_offset_ms=0.0,
    second_leg_delay_ms=0.0,
    post_first_feed_wait="none",
    post_first_feed_timeout_ms=0.0,
    post_first_feed_poll_ms=1.0,
    response_timeout_ms=50.0,
    max_steps=None,
    max_trades_per_pair=None,
    record_market_every_steps=1,
    rebuild_hbt_results=False,
    queue_model="risk_adverse",
    entry_threshold_pct=None,
    exit_threshold_pct=None,
    min_effective_tick_multiple=None,
    min_second_leg_adjusted_basis_pct=None,
    no_second_leg_profit_check=False,
    no_flatten=False,
    continue_on_error=True,
)
args.output_dir.mkdir(parents=True, exist_ok=True)
strategy = FutureSpotPairStrategy()

# %% [markdown]
# ## __Build Daily Pair Config Universe__

# %%
trade_dates = daily_pipeline.select_trade_dates(args.calendar, args.start_date, args.end_date)
records, build_status = daily_pipeline.build_daily_pair_records(args, trade_dates)
reporting.write_csv(build_status, args.output_dir / "daily_config_build_status.csv")

pair_universe = daily_pipeline.pair_universe_frame(records)
reporting.write_csv(pair_universe, args.output_dir / "daily_pair_universe.csv")
pair_universe.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 trade_dates = daily_pipeline.select_trade_dates(args.calendar, args.start_date, args.end_date)
# ----> 2 records, build_status = daily_pipeline.build_daily_pair_records(args, trade_dates)
#       3 reporting.write_csv(build_status, args.output_dir / "daily_config_build_status.csv")
#       4
#       5 pair_universe = daily_pipeline.pair_universe_frame(records)
#
# File ~/hftbacktest/future_spot/arbitrage/full_market_runner.py:607, in build_daily_pair_records(args, trade_dates)
#     605 if needs_rebuild:
#     606     try:
# --> 607         result = build_arbitrage_config_from_date(
#     608             trade_date,
#     609             base_config=args.base_config,
#     610             calendar=args.calendar,
#     611             stockinfo=args.stockinfo,
#     612             futures_parquet_template=args.futures_parquet_template,
#     613             twse_daytrade_template=args.twse_daytrade_template,
#     614             tpex_daytrade_template=args.tpex_daytrade_template,
#     615             twse_daily_template=args.twse_daily_template,
#     616             tpex_daily_template=args.tpex_daily_template,
#     617             session_start=args.build_session_start,
#     618             session_end=args.build_session_end,
#     619             min_future_volume=args.min_future_volume,
#     620             min_stock_volume=args.min_stock_volume,
#     621             required_unit=args.required_unit,
#     622             output=config_path,
#     623             target_output=target_path,
#     624             name_template=args.name_template,
#     625         )
#     626         status = "generated"
#     627         manifest_dates[trade_date] = build_signature
#
# File ~/hftbacktest/future_spot/scripts/build_arbitrage_config_from_date.py:233, in build_arbitrage_config_from_date(trade_date, base_config, calendar, stockinfo, futures_parquet_template, twse_daytrade_template, tpex_daytrade_template, twse_daily_template, tpex_daily_template, session_start, session_end, min_future_volume, min_stock_volume, required_unit, output, target_output, name_template, min_effective_tick_multiple, exit_tick_multiple)
#     229 logging.info("trade_date=%s ldate=%s", trade_date, ldate)
#     231 base = read_json(base_config_path)
# --> 233 futures_ohlcv = build_futures_session_ohlcv(
#     234     path=Path(format_template(futures_parquet_template, trade_date, ldate)),
#     235     session_start=session_start,
#     236     session_end=session_end,
#     237 )
#     238 stock_info = read_stockinfo_frame(Path(stockinfo))
#     239 stock_daily = read_stock_daily(
#     240     trade_date=trade_date,
#     241     ldate=ldate,
#    (...)    245     tpex_daily_template=tpex_daily_template,
#     246 )
#
# File ~/hftbacktest/future_spot/scripts/build_arbitrage_config_from_date.py:333, in build_futures_session_ohlcv(path, session_start, session_end)
#     331 logging.info("reading futures ticks: %s", path)
#     332 ticks = pd.read_parquet(path, columns=columns)
# --> 333 ticks["localtime"] = pd.to_datetime(ticks["exchtime"], unit="ns") + pd.Timedelta(hours=8)
#     334 ticks["future_symbol"] = ticks["symbol"].astype(str).str.slice(0, 2)
#     335 ticks = add_future_status_columns(ticks)
#
# File ~/hftbacktest/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1036, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, origin, cache)
#    1034             result = arg.tz_localize("utc")
#    1035 elif isinstance(arg, ABCSeries):
# -> 1036     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1037     if not cache_array.empty:
#    1038         result = arg.map(cache_array)
#
# File ~/hftbacktest/.venv/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:252, in _maybe_cache(arg, format, cache, convert_listlike)
#     249 if not isinstance(arg, (np.ndarray, ExtensionArray, Index, ABCSeries)):
#     250     arg = np.array(arg)
# --> 252 unique_dates = unique(arg)
#     253 if len(unique_dates) < len(arg):
#     254     cache_dates = convert_listlike(unique_dates, format)
#
# File ~/hftbacktest/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:433, in unique(values)
#     327 @set_module("pandas")
#     328 def unique(values):
#     329     """
#     330     Return unique values based on a hash table.
#     331
#    (...)    431     Length: 3, dtype: complex128
#     432     """
# --> 433     return unique_with_mask(values)
#
# File ~/hftbacktest/.venv/lib/python3.12/site-packages/pandas/core/algorithms.py:476, in unique_with_mask(values, mask)
#     474 table = hashtable(len(values))
#     475 if mask is None:
# --> 476     uniques = table.unique(values)
#     477     uniques = _reconstruct_data(uniques, original.dtype, original)
#     478     return uniques
#
# KeyboardInterrupt:

# %% [markdown]
# ## __Build / Reuse HBT Event Data__

# %%
event_paths, conversion_status = event_data.build_event_data(args, records)
reporting.write_csv(conversion_status, args.output_dir / "conversion_status.csv")
conversion_status.head(10)

# %% [markdown]
# ## __Run HBT With Strategy Adapter__

# %%
# hbt_pipeline.run_backtests uses the default FutureSpotPairStrategy internally.
# For a custom strategy, instantiate HbtPairBacktester directly with strategy=<your adapter>.
pair_results, summary, trades, market, latency, run_errors = hbt_pipeline.run_or_load_backtests(args, records, event_paths)
reporting.write_csv(summary, args.output_dir / "summary_all_daily_pairs.csv")
reporting.write_csv(trades, args.output_dir / "trades_all_daily_pairs.csv")
reporting.write_csv(market, args.output_dir / "market_all_daily_pairs.csv")
reporting.write_csv(latency, args.output_dir / "latency_all_daily_pairs.csv")
reporting.write_csv(run_errors, args.output_dir / "run_errors.csv")
summary.head(10)

# %% [markdown]
# ## __Entry / Exit Output__

# %%
entry_exit_by_pair, entry_exit_all, entry_exit_index = reporting.build_entry_exit_outputs(pair_results, records)
reporting.write_csv(entry_exit_all, args.output_dir / "entry_exit_all_daily_pairs.csv")
reporting.write_csv(entry_exit_index, args.output_dir / "entry_exit_index.csv")
entry_exit_index.head(10)
